# %%
import ccxt
from pprint import pprint

# %%
#取引所の指定
cc = ccxt.coincheck()

# %%
#loadMarkets(マーケット情報の取得)
markets = cc.loadMarkets()
#pprint(markets)

# %%
#fetchMarkets(マーケット情報を取得)
"""
loadMarketsの方が良い（キャッシュに保存してくれるので不要なリクエストが必要なくなるから）
"""
#markets = cc.fetchMarkets()
#pprint(markets)

# %%
#fetchCurrencies(取引所で取り扱われている通貨の取得)
currencies = cc.fetchCurrencies()
#pprint(currencies)

# %%
#fetchTicker(特定の市場の最新の価格情報や統計を取得)
ticker = cc.fetchTicker(symbol='BTC/JPY')
pprint(ticker)
# Out:
# {'ask': 7797850.0,
#  'askVolume': None,
#  'average': None,
#  'baseVolume': 1576.63213669,
#  'bid': 7797398.0,
#  'bidVolume': None,
#  'change': None,
#  'close': 7797398.0,
#  'datetime': '2024-02-22T07:38:00.000Z',
#  'high': 7820000.0,
#  'info': {'ask': '7797850.0',
#           'bid': '7797398.0',
#           'high': '7820000.0',
#           'last': '7797398.0',
#           'low': '7634567.0',
#           'timestamp': '1708587480',
#           'volume': '1576.63213669'},
#  'last': 7797398.0,
#  'low': 7634567.0,
#  'open': None,
#  'percentage': None,
#  'previousClose': None,
#  'quoteVolume': None,
#  'symbol': 'BTC/JPY',
#  'timestamp': 1708587480000,
#  'vwap': None}

# %%
# fetchTickers(複数の市場の最新のティッカー情報を一括で取得)
tickers = cc.fetchTickers()
# tickers
# Out:
# ---------------------------------------------------------------------------
# NotSupported                              Traceback (most recent call last)
# Cell In[25], line 2
#       1 #fetchTickers(複数の市場の最新のティッカー情報を一括で取得)
# ----> 2 tickers = cc.fetchTickers()
#       3 tickers
#
# File /opt/conda/lib/python3.11/site-packages/ccxt/base/exchange.py:3936, in Exchange.fetch_tickers(self, symbols, params)
#    3935 def fetch_tickers(self, symbols: List[str] = None, params={}):
# -> 3936     raise NotSupported(self.id + ' fetchTickers() is not supported yet')
#
# NotSupported: coincheck fetchTickers() is not supported yet

# %%
#fetchOrderBook(特定の市場の注文簿を取得)
#bids:買い注文のリスト，asks:売り注文のリスト
book = cc.fetchOrderBook(symbol='BTC/JPY')
pprint(book)
# Out:
# {'asks': [[7806626.0, 0.05],
#           [7806627.0, 0.00013],
#           [7807220.0, 0.005],
#           [7807349.0, 0.1],
#           [7807625.0, 0.02],
#           [7807965.0, 0.0447],
#           [7807966.0, 0.0232],
#           [7808238.0, 0.0195],
#           [7808283.0, 0.01],
#           [7808332.0, 0.01973609],
#           [7808510.0, 0.11846617],
#           [7808512.0, 0.07475969],
#           [7808578.0, 0.03633485],
#           [7808763.0, 0.06],
#           [7808908.0, 0.01],
#           [7809004.0, 0.0909],
#           [7809320.0, 0.005],
#           [7809763.0, 0.06],
#           [7809928.0, 0.01024738],
#           [7809939.0, 0.00865221],
#           [7809940.0, 0.01024709],
#           [7809941.0, 0.00948064],
#           [7810000.0, 2.1555128],
#           [7810227.0, 0.02],
#           [7810363.0, 0.02866],
#           [7810479.0, 0.01],
#           [7810691.0, 0.05],
#           [7811077.0, 0.005],
#           [7811195.0, 0.005127],
#           [7811294.0, 0.07031015],
#           [7812345.0, 0.07],
#           [7812436.0, 0.005],
#           [7812912.0, 0.2046],
#           [7813000.0, 0.1],
#           [7815000.0, 1.01023672],
#           [7816035.0, 0.3174],
#           [7816717.0, 0.01],
#           [7817623.0, 0.006],
#           [7818000.0, 0.1],
#           [7818732.0, 0.01],
#           [7819536.0, 0.01],
#           [7819939.0, 0.5988],
#           [7819995.0, 0.005],
#           [7819998.0, 0.005],
#           [7819999.0, 0.005],
#           [7820000.0, 2.15129302],
#           [7821100.0, 0.01],
#           [7821234.0, 0.005],
#           [7821355.0, 0.2],
#           [7822000.0, 0.1726979],
#           [7822555.0, 0.1],
#           [7822856.0, 0.005],
#           [7823000.0, 0.11391409],
#           [7823843.0, 0.5988],
#           [7824000.0, 0.07029652],
#           [7824534.0, 0.01],
#           [7825000.0, 0.81889776],
#           [7826420.0, 0.005],
#           [7827476.0, 0.1],
#           [7827770.0, 0.02],
#           [7828125.0, 0.00512],
#           [7828970.0, 0.005],
#           [7829024.0, 0.2],
#           [7829419.0, 0.01],
#           [7829999.0, 0.005],
#           [7830000.0, 2.34299],
#           [7830123.0, 0.006],
#           [7832000.0, 0.0253],
#           [7832359.0, 0.01],
#           [7832500.0, 1.0],
#           [7833210.0, 0.2],
#           [7833776.0, 0.005],
#           [7834054.0, 1.1959],
#           [7834349.0, 0.05224818],
#           [7834998.0, 0.005],
#           [7835000.0, 1.21021059],
#           [7835054.0, 0.01],
#           [7835250.0, 0.07435081],
#           [7836711.0, 0.02],
#           [7837000.0, 0.5],
#           [7837800.0, 0.15],
#           [7838000.0, 1.0],
#           [7839027.0, 0.11],
#           [7839876.0, 0.05739886],
#           [7839999.0, 3.035],
#           [7840000.0, 2.64148184],
#           [7840191.0, 0.01],
#           [7841544.0, 0.01],
#           [7842623.0, 0.006],
#           [7843000.0, 0.005],
#           [7844000.0, 0.02],
#           [7844200.0, 0.27],
#           [7844353.0, 0.05],
#           [7845000.0, 1.1097],
#           [7848000.0, 0.05096839],
#           [7848031.0, 0.01],
#           [7848516.0, 0.2],
#           [7849000.0, 0.029],
#           [7849425.0, 0.01],
#           [7849470.0, 0.005102],
#           [7849500.0, 0.07],
#           [7849998.0, 0.015],
#           [7849999.0, 0.20358038],
#           [7850000.0, 4.00240528],
#           [7850720.0, 0.005],
#           [7851000.0, 0.01],
#           [7851406.0, 0.8051],
#           [7852466.0, 0.3993],
#           [7853669.0, 0.02027148],
#           [7853727.0, 0.2],
#           [7855000.0, 0.01018459],
#           [7855123.0, 0.006],
#           [7855500.0, 0.01],
#           [7855879.0, 0.01],
#           [7856406.0, 0.00636423],
#           [7857000.0, 0.03],
#           [7858000.0, 0.14],
#           [7858413.0, 0.005],
#           [7858712.0, 0.005096],
#           [7858824.0, 0.0051],
#           [7859000.0, 0.1],
#           [7859643.0, 0.10202954],
#           [7859876.0, 0.06361423],
#           [7859999.0, 0.01],
#           [7860000.0, 4.45278812],
#           [7860031.0, 0.01],
#           [7863000.0, 0.03],
#           [7863525.0, 0.05],
#           [7863735.0, 0.01],
#           [7864998.0, 0.005],
#           [7866000.0, 0.02],
#           [7866111.0, 0.2],
#           [7867623.0, 0.006],
#           [7868000.0, 0.27840668],
#           [7868232.0, 0.44],
#           [7868892.0, 0.005],
#           [7869000.0, 0.1],
#           [7870000.0, 1.570015],
#           [7870191.0, 0.1],
#           [7870862.0, 0.01],
#           [7871234.0, 0.005],
#           [7871599.0, 0.01],
#           [7872470.0, 0.005],
#           [7873050.0, 0.05447128],
#           [7873737.0, 0.005],
#           [7875361.0, 0.01],
#           [7875700.0, 0.01],
#           [7875720.0, 0.005],
#           [7877000.0, 0.09],
#           [7878000.0, 0.05],
#           [7878499.0, 0.3993],
#           [7879471.0, 0.01],
#           [7879876.0, 0.13379805],
#           [7879900.0, 0.005],
#           [7879998.0, 0.005],
#           [7879999.0, 0.005],
#           [7880000.0, 0.6832],
#           [7880123.0, 0.006],
#           [7881689.0, 0.005],
#           [7882170.0, 0.02],
#           [7882664.0, 0.0154],
#           [7882697.0, 0.01],
#           [7885000.0, 0.24],
#           [7887350.0, 0.01],
#           [7888000.0, 0.02],
#           [7888440.0, 0.01],
#           [7889764.0, 0.00508],
#           [7889999.0, 0.005],
#           [7890000.0, 0.16433713],
#           [7890001.0, 0.073],
#           [7890858.0, 0.005],
#           [7891000.0, 0.02],
#           [7892623.0, 0.006],
#           [7894000.0, 0.2],
#           [7894220.0, 0.005],
#           [7894615.0, 0.3],
#           [7894998.0, 0.005],
#           [7895237.0, 0.01],
#           [7896039.0, 0.0075],
#           [7897000.0, 0.0077],
#           [7899600.0, 0.4],
#           [7899723.0, 0.01],
#           [7899876.0, 0.07595055],
#           [7899889.0, 0.0099],
#           [7899999.0, 0.01],
#           [7900000.0, 6.03116552],
#           [7900124.0, 0.01317],
#           [7903132.0, 0.01],
#           [7903795.0, 0.05],
#           [7905123.0, 0.006],
#           [7909334.0, 0.01],
#           [7909998.0, 0.005],
#           [7909999.0, 0.02],
#           [7910000.0, 0.3554252],
#           [7911000.0, 0.4422],
#           [7911035.0, 0.01],
#           [7911970.0, 0.006],
#           [7914000.0, 0.085],
#           [7915000.0, 0.016],
#           [7915970.0, 0.005]],
#  'bids': [[7803763.0, 0.01],
#           [7803757.0, 0.007],
#           [7803753.0, 0.05],
#           [7803752.0, 0.00865221],
#           [7803744.0, 0.0516349],
#           [7803743.0, 0.01024709],
#           [7803735.0, 0.01024738],
#           [7803714.0, 0.2],
#           [7803310.0, 0.05],
#           [7803308.0, 0.0133],
#           [7803235.0, 0.0178],
#           [7803206.0, 0.04],
#           [7803145.0, 0.005],
#           [7802901.0, 0.01],
#           [7802820.0, 0.04],
#           [7802127.0, 0.2046],
#           [7801883.0, 0.065],
#           [7801648.0, 0.02],
#           [7800948.0, 0.02],
#           [7800512.0, 0.0908],
#           [7799706.0, 0.3174],
#           [7799705.0, 0.0447],
#           [7799429.0, 0.00641072],
#           [7797196.0, 0.021],
#           [7796559.0, 0.00948064],
#           [7796517.0, 0.005],
#           [7796500.0, 0.5988],
#           [7795807.0, 0.231],
#           [7795797.0, 2.18912313],
#           [7793704.0, 0.0513],
#           [7793567.0, 0.0179],
#           [7793314.0, 0.01],
#           [7792765.0, 0.0179],
#           [7792595.0, 0.5988],
#           [7790002.0, 0.005],
#           [7790000.0, 0.29525031],
#           [7789878.0, 0.01],
#           [7787015.0, 0.005],
#           [7785528.0, 0.01],
#           [7784787.0, 1.1959],
#           [7783000.0, 0.1],
#           [7780001.0, 0.005],
#           [7778164.0, 0.0419],
#           [7777750.0, 0.01],
#           [7777225.0, 0.01],
#           [7775002.0, 0.005],
#           [7775000.0, 0.03069607],
#           [7774267.0, 0.02],
#           [7773999.0, 0.0179],
#           [7772000.0, 0.005],
#           [7771297.0, 0.2],
#           [7771001.0, 0.005],
#           [7771000.0, 0.05],
#           [7770001.0, 0.005],
#           [7770000.0, 0.13],
#           [7769980.0, 0.01],
#           [7765000.0, 0.05],
#           [7763720.0, 0.005],
#           [7763188.0, 0.8051],
#           [7762218.0, 0.01],
#           [7761000.0, 0.76637662],
#           [7760002.0, 0.005],
#           [7760001.0, 0.005],
#           [7760000.0, 0.05],
#           [7758674.0, 0.0419],
#           [7754464.0, 0.01],
#           [7751291.0, 0.3993],
#           [7751111.0, 0.00645068],
#           [7750751.0, 0.00370592],
#           [7750000.0, 0.52990364],
#           [7749504.0, 0.0258081],
#           [7748454.0, 0.0258116],
#           [7747170.0, 0.02581074],
#           [7746717.0, 0.01],
#           [7745848.0, 0.02582028],
#           [7745002.0, 0.005],
#           [7743247.0, 0.02206413],
#           [7741970.0, 0.005],
#           [7741111.0, 0.00645902],
#           [7741000.0, 1.87998966],
#           [7740500.0, 0.01291906],
#           [7740001.0, 0.01],
#           [7740000.0, 1.18666864],
#           [7738978.0, 0.01],
#           [7738245.0, 0.18],
#           [7736313.0, 0.005001],
#           [7736195.0, 0.2],
#           [7736163.0, 0.03877891],
#           [7732000.0, 0.1],
#           [7731247.0, 0.01],
#           [7731111.0, 0.01293475],
#           [7731000.0, 0.35],
#           [7730002.0, 0.005],
#           [7730000.0, 0.2724],
#           [7728770.0, 0.3993],
#           [7728000.0, 0.015],
#           [7727090.0, 1.0],
#           [7726163.0, 0.0388291],
#           [7723523.0, 0.01],
#           [7723000.0, 0.12948323],
#           [7721234.0, 0.005],
#           [7720220.0, 0.005],
#           [7720001.0, 0.005],
#           [7720000.0, 0.15],
#           [7716163.0, 0.03887942],
#           [7715807.0, 0.01],
#           [7715002.0, 0.005],
#           [7714000.0, 0.098],
#           [7711629.0, 0.1],
#           [7711111.0, 0.01945244],
#           [7711000.0, 0.05],
#           [7710001.0, 0.005],
#           [7710000.0, 0.11485084],
#           [7708300.0, 0.05],
#           [7708099.0, 0.01],
#           [7707210.0, 0.01297486],
#           [7706321.0, 0.0075],
#           [7705734.0, 0.01297734],
#           [7705123.0, 0.006],
#           [7705000.0, 0.01],
#           [7701456.0, 0.0402],
#           [7701254.0, 0.2],
#           [7701234.0, 0.005],
#           [7700399.0, 0.01],
#           [7700119.0, 0.0153],
#           [7700002.0, 0.005],
#           [7700001.0, 0.07],
#           [7700000.0, 1.40958437],
#           [7699000.0, 0.03],
#           [7698470.0, 0.005],
#           [7692706.0, 0.01],
#           [7692623.0, 0.006],
#           [7691111.0, 0.02600404],
#           [7690000.0, 0.22450585],
#           [7689668.0, 0.0999999],
#           [7689491.0, 0.1],
#           [7688733.0, 0.1],
#           [7688349.0, 0.1],
#           [7686800.0, 0.02],
#           [7686182.0, 0.0591972],
#           [7685724.0, 0.02602227],
#           [7685021.0, 0.01],
#           [7685002.0, 0.005],
#           [7682521.0, 0.02604595],
#           [7680667.0, 0.02],
#           [7680123.0, 0.006],
#           [7680001.0, 0.01],
#           [7680000.0, 0.334],
#           [7678736.0, 0.02604595],
#           [7677344.0, 0.01],
#           [7676800.0, 0.02],
#           [7676720.0, 0.005],
#           [7676000.0, 0.5],
#           [7675000.0, 0.10202931],
#           [7672000.0, 0.005],
#           [7671234.0, 0.005],
#           [7671111.0, 0.0325898],
#           [7670002.0, 0.005],
#           [7670000.0, 0.27],
#           [7669674.0, 0.01],
#           [7668800.0, 0.02],
#           [7667623.0, 0.006],
#           [7666050.0, 0.05505526],
#           [7666000.0, 0.03261152],
#           [7665000.0, 1.39],
#           [7662012.0, 0.01],
#           [7660365.0, 0.02610841],
#           [7660321.0, 0.04007664],
#           [7660001.0, 0.005],
#           [7660000.0, 0.96716578],
#           [7659557.0, 0.01],
#           [7658950.0, 0.02611324],
#           [7658581.0, 0.02611449],
#           [7658000.0, 0.02],
#           [7656800.0, 0.02],
#           [7655123.0, 0.006],
#           [7655002.0, 0.005],
#           [7655000.0, 0.09075518],
#           [7654970.0, 0.005],
#           [7654358.0, 0.01],
#           [7653000.0, 0.02],
#           [7651254.0, 0.2],
#           [7651234.0, 0.005],
#           [7651111.0, 0.03920999],
#           [7651000.0, 0.02],
#           [7650119.0, 0.02],
#           [7650101.0, 0.01],
#           [7650077.0, 0.327],
#           [7650010.0, 0.01],
#           [7650005.0, 0.1],
#           [7650001.0, 0.155],
#           [7650000.0, 2.41143255],
#           [7649100.0, 0.1],
#           [7649000.0, 0.08670375],
#           [7646711.0, 0.01],
#           [7645000.0, 0.01083217],
#           [7642623.0, 0.006],
#           [7640007.0, 0.005],
#           [7640002.0, 0.005],
#           [7640001.0, 0.005]],
#  'datetime': None,
#  'nonce': None,
#  'symbol': 'BTC/JPY',
#  'timestamp': None}

# %%
#fetchOHLCV

# %%
#fetchStatus

# %%
#fetchTrades
